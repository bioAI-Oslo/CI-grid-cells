# %%
# %load_ext autoreload
# %autoreload 2
#%matplotlib notebook
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
from methods import *

# %%
f = 1
orientation_offset = 0
center = np.zeros(2)

# %%
enclosing_hexagon_circle_radius = 1 / (2*f)
hexagon = Hexagon(enclosing_hexagon_circle_radius, orientation_offset, center)

# show defining hexagon points (and center)
plt.scatter(*hexagon.hpoints.T)
plt.scatter(*center)
plt.axis('equal')
# Out:
# (-0.55, 0.55, -0.47631397208144144, 0.47631397208144133)

# %%
for i in range(len(hexagon.hpoints)+10):
    plt.plot(*hexagon.hpoints[i:(i+2)].T, color='red')

plt.scatter(*hexagon.sample(1000).T)
plt.axis('equal')
# Out:
# (-0.55, 0.55, -0.47631397208144144, 0.47631397208144133)

# %%
#grid_module = grid_cell(np.random.uniform(0,1,(10,2)),0,1)
grid_module = grid_cell(hexagon.hpoints,0,1)

# %%
nx,ny = 2,2 # board size

# initialize board
xx, yy = np.meshgrid(
    np.linspace(-nx/2, nx/2, 64),
    np.linspace(-ny/2, ny/2, 64),
)
board = np.stack([xx, yy], axis=-1)
zz = np.zeros(list(board.shape[:-1])+[3])

# %%
grid_module(board).shape
# Out:
# (6, 64, 64)

# %%
plt.imshow(np.sum(grid_module(board),axis=0))
plt.colorbar()

# %%
for grid in grid_module(board):
    plt.imshow(grid)
    plt.show()
